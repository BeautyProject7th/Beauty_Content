# %% [markdown]
# # [유튜버 리스트 정리]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# ## 1. "검색어 : 메이크업" 주소 저장

# %%
query = "메이크업"
url = "https://www.youtube.com/results?search_query=" + query
driver = webdriver.Firefox()
page_address = driver.get(url)
page_html = driver.page_source
page_bs = BeautifulSoup(page_html)
print(page_bs)
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ...

# %%
total_url = []

# %%
for via in page_bs.find_all("a", {"class", "yt-uix-button vve-check yt-uix-sessionlink yt-uix-button-default yt-uix-button-size-default"}):
    total_url.append

# %% [markdown]
# ## 2. BeautifulSoup

# %%
driver = webdriver.Firefox()

# %%
result = driver.get(browse_site)

# %%
result_html = driver.page_source
result_bs = BeautifulSoup(result_html)
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
# ### 결과 확인

# %%
print(result_bs.prettify())
# Out:
# <html class="guide-pinned show-guide" data-cast-api-enabled="true" lang="ko">
#  <head>
#   <script async="" class="js-httpswwwyoutubecomytsjsbinplayervfluaMKo6ko_KRbasejs" name="player/ko_KR/base" src="https://www.youtube.com/yts/jsbin/player-vfluaMKo6/ko_KR/base.js">
#   </script>
#   <script async="" class="js-httpswwwyoutubecomytsjsbinwwwen_USvfl4F02J4commonjs" name="www/common" src="https://www.youtube.com/yts/jsbin/www-en_US-vfl4F02J4/common.js">
#   </script>
#   <script async="" class="js-httpswwwyoutubecomytsjsbinwwwpageframevflWMvmEDwwwpageframejs" name="www-pageframe/www-pageframe" src="https://www.youtube.com/yts/jsbin/www-pageframe-vflWMvmED/www-pageframe.js">
#   </script>
#   <style name="www-roboto" nonce="">
# ...

# %% [markdown]
# ### 2-1. 걸러내기

# %%
youtuber = result_bs.find_all("a", {"class" : "g-hovercard yt-uix-sessionlink spf-link "})

# %%
youtuber = str(youtuber)

# %%
space = " "

# %%
youtuber = space + youtuber

# %%
youtuber = youtuber.split("</a>")

# %%
len(youtuber)
# Out:
# 21

# %%
for i in range(len(youtuber)-1):
    middle = youtuber[i]
    final = middle[164:]
    final = final.split("\">")
    line_youtuber = [final[0], final[1]]
    add_youtuber.append(line_youtuber)

# %%
add_youtuber
# Out:
# [['/user/yooncharmi', '윤쨔미 YoonCharmi'],
#  ['/user/yumcast11', '윰댕(yum-cast)'],
#  ['/channel/UCZggbgiMY7u4Def37xQpyAQ', '아름송이 areumsongee'],
#  ['/channel/UCuZu8NrpBG4WPXRi-hPBl-A', 'Yojin 조효진'],
#  ['/channel/UCTUpo6hxbwGMNT1faQgwENg', 'BBOOM STAR'],
#  ['/user/Mr19940711', '혜서니'],
#  ['/channel/UC9kmlDcqksaOnCkC_qzGacA', 'Risabae 이사배'],
#  ['/channel/UC9gW47NqzI1x7e8qsflvUUw', 'Hanbyul 한별'],
#  ['/user/doublej0128', 'Sae Byeock'],
#  ['/channel/UCU8mou_JjcF-IXZMkAqpA6g', "Lena's Pocket Beauty"],
#  ['/channel/UCfTswP_uNy_h86pUjCU410A', 'HANA 김하나'],
#  ['/user/Hines382', 'ssin 씬님'],
#  ['/channel/UCU8mou_JjcF-IXZMkAqpA6g', "Lena's Pocket Beauty"],
#  ['/channel/UCU8mou_JjcF-IXZMkAqpA6g', "Lena's Pocket Beauty"],
#  ['/user/Hines382', 'ssin 씬님'],
#  ['/user/yooncharmi', '윤쨔미 YoonCharmi'],
#  ['/user/calarygirl', 'Calary Girl'],
#  ['/channel/UCDih-87kuRMA8uFcrx10Wlw', '미디어텍'],
#  ['/channel/UCzzt6bFEBcy-CoZeFvTSq0A', "GOSOO's Daily Snap 평범해도 괜찮아"],
# ...

# %% [markdown]
# ## 3. Dataframe 저장

# %%
import pandas as pd

# %%
youtuberCol = ["유튜버주소", "유튜버"]

# %%
df = pd.DataFrame(add_youtuber, columns = youtuberCol)

# %%
df
# Out:
#                                 유튜버주소                          유튜버
# 0                    /user/yooncharmi               윤쨔미 YoonCharmi
# 1                     /user/yumcast11                 윰댕(yum-cast)
# 2   /channel/UCZggbgiMY7u4Def37xQpyAQ             아름송이 areumsongee
# 3   /channel/UCuZu8NrpBG4WPXRi-hPBl-A                    Yojin 조효진
# 4   /channel/UCTUpo6hxbwGMNT1faQgwENg                   BBOOM STAR
# 5                    /user/Mr19940711                          혜서니
# 6   /channel/UC9kmlDcqksaOnCkC_qzGacA                  Risabae 이사배
# 7   /channel/UC9gW47NqzI1x7e8qsflvUUw                   Hanbyul 한별
# 8                   /user/doublej0128                   Sae Byeock
# 9   /channel/UCU8mou_JjcF-IXZMkAqpA6g         Lena's Pocket Beauty
# 10  /channel/UCfTswP_uNy_h86pUjCU410A                     HANA 김하나
# 11                     /user/Hines382                      ssin 씬님
# 12  /channel/UCU8mou_JjcF-IXZMkAqpA6g         Lena's Pocket Beauty
# ...

# %%
import urllib
from urllib.request import urlopen
import urllib.parse
from bs4 import BeautifulSoup
# Out:
# /Users/SeulA/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/SeulA/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# ...

# %%
import cv2
import dlib
import numpy
import sys

# %%
import matplotlib.pyplot as plt

# %%
from skimage.feature import hog

# %%
from matplotlib import pyplot as plt

# %%
from PIL import Image
from PIL import ImageDraw

# %%
from skimage import data, color, exposure

# %%
# %matplotlib inline

# %%
PATH1 = "./skinfood.png"
image = cv2.imread(PATH1, 0)

# %%
plt.imshow(image)
plt.show()

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 100))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 90))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 80))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 70))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 60))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 50))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 40))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 30.2))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 20.2))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 20.2))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10.2))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10.2))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 5.2))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)

# %%
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(2, 2), cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

ax1.axis('off')
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 5.2))
ax1.imshow(hog_image_rescaled, cmap=plt.cm.gray)

hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 0.2))
ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)

plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/feature/_hog.py:119: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15
#   'be changed to `L2-Hys` in v0.15', skimage_deprecation)
